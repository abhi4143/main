# %% [markdown]
# # 20MAI0005

# %% [markdown]
# # Abhishek Kumar

# %% [markdown]
# # Web Scrapping

# %% [markdown]
# # Introduction:
# At a time when the internet is so data rich and data has apparently become the new oil, web scraping has become even more important and practical in various applications. Web scraping is also known as web harvesting or web data mining. Copying text from a website and pasting it into your local system is also web scraping. However, it is a manual task. In general, web scraping is about extracting data automatically using web crawlers. Web crawlers are scripts that connect to the World Wide Web using the HTTP protocol and allow you to retrieve data in an automated manner. We are data scientists, engineers or anyone else who analyzes large amounts of data sets. the ability to extract data from the web is a useful skill. For example, suppose you find data from the web and there is no direct way to download it. Web scraping with Python is a skill that allows you to extract the data into a useful form that can then be imported and used in a variety of ways. Some of the practical uses of web scraping could be: compiling résumés of candidates with a particular skillExtract Twitter Tweets with Specific Hashtags, Generate Marketing Leads, Scraping Product Details, and Ecommerce Website Reviews Potential Web Scraping Challenges: One of the challenges of gathering information from websites is the different structures of the websites. That said, the website templates are different and unique. Generalizing across websites could therefore be challenging. Another challenge could be longevity. Because web developers are constantly updating their websites, a scraper cannot be trusted for too long. The changes are minor, but they can still be an obstacle for you while you are getting the data.

# %% [markdown]
# # Importing necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import re
import time
from datetime import datetime
import matplotlib.dates as mdates
import matplotlib.ticker as ticker
from urllib.request import urlopen
from bs4 import BeautifulSoup
import requests

# %% [markdown]
# # Scrapping the Amazon Best Selling Books

# %%
no_pages = 2

def get_data(pageNo):  
    headers = {"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:66.0) Gecko/20100101 Firefox/66.0", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    r = requests.get('https://www.amazon.in/gp/bestsellers/books/ref=zg_bs_pg_'+str(pageNo)+'?ie=UTF8&pg='+str(pageNo), headers=headers)#, proxies=proxies)
    content = r.content
    soup = BeautifulSoup(content)
    #print(soup)

    alls = []
    for d in soup.findAll('div', attrs={'class':'a-section a-spacing-none aok-relative'}):
        #print(d)
        name = d.find('span', attrs={'class':'zg-text-center-align'})
        n = name.find_all('img', alt=True)
        #print(n[0]['alt'])
        author = d.find('a', attrs={'class':'a-size-small a-link-child'})
        rating = d.find('span', attrs={'class':'a-icon-alt'})
        users_rated = d.find('a', attrs={'class':'a-size-small a-link-normal'})
        price = d.find('span', attrs={'class':'p13n-sc-price'})

        all1=[]

        if name is not None:
            #print(n[0]['alt'])
            all1.append(n[0]['alt'])
        else:
            all1.append("unknown-product")

        if author is not None:
            #print(author.text)
            all1.append(author.text)
        elif author is None:
            author = d.find('span', attrs={'class':'a-size-small a-color-base'})
            if author is not None:
                all1.append(author.text)
            else:    
                all1.append('0')

        if rating is not None:
            #print(rating.text)
            all1.append(rating.text)
        else:
            all1.append('-1')

        if users_rated is not None:
            #print(price.text)
            all1.append(users_rated.text)
        else:
            all1.append('0')     

        if price is not None:
            #print(price.text)
            all1.append(price.text)
        else:
            all1.append('0')
        alls.append(all1)    
    return alls

# %%
#creating the csv file of scrapped data from Amazon best seeling books web page
results = []
for i in range(1, no_pages+1):
    results.append(get_data(i))
flatten = lambda l: [item for sublist in l for item in sublist]
df = pd.DataFrame(flatten(results),columns=['Book Name','Author','Rating','Customers_Rated', 'Price']) 
df.to_csv('amazon_products.csv', index=False, encoding='utf-8')

# %% [markdown]
# # Loading the created file after scrapping

# %%
df = pd.read_csv("amazon_products.csv")
df.shape #Display the number of records in the above loaded file
# Out:
# (100, 5)

# %%
df.shape
# Out:
# (100, 5)

# %%
df.head(61)
# Out:
#                                             Book Name                 Author  \
# 0   Karma: A Yogi's Guide to Crafting Your Destiny...      Sadhguru (Author)
# 1   My First Book of Patterns Pencil Control: Patt...     Wonder House Books
# 2   My First Library: Boxset of 10 Board Books for...     Wonder House Books
# 3   Ikigai: The Japanese secret to a long and happ...          Héctor García
# 4   Grandma's Bag of Stories: Collection of 20+ Il...            Sudha Murty
# ..                                                ...                    ...
# 56  Animals Tales From Panchtantra: Timeless Stori...     Wonder House Books
# 57      PERFECTION BOOK - ENGLISH WITH NIMISHA BANSAL         NIMISHA BANSAL
# 58  Mathematics for Class 10 by R D Sharma (Examin...            R.D. Sharma
# 59                       Grandparents' Bag of Stories            Sudha Murty
# 60  India & World Map ( Both Political & Physical ...  Vidya Chitr Prakashan
#
#                 Rating Customers_Rated     Price
# 0   4.6 out of 5 stars             257  ₹ 260.00
# 1   4.4 out of 5 stars           5,171   ₹ 89.00
# 2   4.5 out of 5 stars          22,879  ₹ 399.00
# 3   4.6 out of 5 stars          14,155  ₹ 329.00
# 4   4.6 out of 5 stars           5,229  ₹ 198.00
# ..                 ...             ...       ...
# 56  4.6 out of 5 stars             736  ₹ 159.00
# 57  4.6 out of 5 stars              70  ₹ 350.00
# 58  4.6 out of 5 stars           1,494  ₹ 452.00
# 59  4.8 out of 5 stars             506  ₹ 140.00
# 60  4.6 out of 5 stars              95  ₹ 180.00
#
# [61 rows x 5 columns]

# %%
#Displaying last 5 records
df.tail()
# Out:
#                                             Book Name                  Author  \
# 95           Inner Engineering: A Yogi’s Guide to Joy                Sadhguru
# 96                    My Activity- ABC Colouring Book  Dreamland Publications
# 97  Bharat Ki Rajvyavastha - Civil Seva Evam Anya ...           M. Laxmikanth
# 98  My First Mythology Tale (Illustrated) (Set of ...             Maple Press
# 99  Alphabets Writing Book - Capital Letters (Prac...             Maple Press
#
#                 Rating Customers_Rated     Price
# 95  4.6 out of 5 stars           9,326  ₹ 211.00
# 96  4.4 out of 5 stars           1,494  ₹ 100.00
# 97  4.5 out of 5 stars           2,573  ₹ 540.00
# 98  4.4 out of 5 stars             363  ₹ 191.00
# 99  4.5 out of 5 stars             317   ₹ 80.00

# %% [markdown]
# # Data Preprocessing

# %%
#Since we know the ratings are out of 5, we can keep only the rating and remove the extra part from it.
#From the customers_rated column, remove the comma.
#From the price column, remove the rupees symbol, comma, and split it by dot.
#Finally, convert all the three columns into integer or float.

df['Rating'] = df['Rating'].apply(lambda x: x.split()[0])
df['Rating'] = pd.to_numeric(df['Rating'])
df["Price"] = df["Price"].str.replace('₹', '')
df["Price"] = df["Price"].str.replace(',', '')
df['Price'] = df['Price'].apply(lambda x: x.split('.')[0])
df['Price'] = df['Price'].astype(int)
df["Customers_Rated"] = df["Customers_Rated"].str.replace(',', '')
df['Customers_Rated'] = pd.to_numeric(df['Customers_Rated'], errors='ignore')

# %%
# Top 5 Data after preprocessing 
df.head()
# Out:
#                                            Book Name              Author  \
# 0  Karma: A Yogi's Guide to Crafting Your Destiny...   Sadhguru (Author)
# 1  My First Book of Patterns Pencil Control: Patt...  Wonder House Books
# 2  My First Library: Boxset of 10 Board Books for...  Wonder House Books
# 3  Ikigai: The Japanese secret to a long and happ...       Héctor García
# 4  Grandma's Bag of Stories: Collection of 20+ Il...         Sudha Murty
#
#    Rating  Customers_Rated  Price
# 0     4.6              257    260
# 1     4.4             5171     89
# 2     4.5            22879    399
# 3     4.6            14155    329
# 4     4.6             5229    198

# %%
#Let's verify the data types
df.dtypes
# Out:
# Book Name           object
# Author              object
# Rating             float64
# Customers_Rated      int64
# Price                int32
# dtype: object

# %%
#Replace the zero values in the DataFrame to NaN
df.replace(str(0), np.nan, inplace=True)
df.replace(0, np.nan, inplace=True)

# %%
#Counting the Number of NaNs in the DataFrame
count_nan = len(df) - df.count()
count_nan
# Out:
# Book Name          0
# Author             1
# Rating             0
# Customers_Rated    0
# Price              0
# dtype: int64

# %%
#Let's drop these NaNs
df = df.dropna()

# %%
#Authors Highest Priced Book
data = df.sort_values(["Price"], axis=0, ascending=False)[:15]
data
# Out:
#                                             Book Name  \
# 39  NCERT textbooks physics, chemistry and biology...
# 52  Atomic Habits: The life-changing million copy ...
# 6   Indian Polity - For Civil Services and Other S...
# 66  A Modern Approach to Verbal & Non-Verbal Reaso...
# 46  Objective NCERT at your FINGERTIPS for NEET-AI...
# 86  Indian Art and Culture for Civil Services and ...
# 97  Bharat Ki Rajvyavastha - Civil Seva Evam Anya ...
# 72  Stories I Must Tell: The Emotional Life of an ...
# 65  The Intelligent Investor (English) Paperback –...
# 55  Best of Children’s Classics (Set of 5 Books): ...
# 8   Quantitative Aptitude for Competitive Examinat...
# 12  Rich Dad Poor Dad: What the Rich Teach Their K...
# 58  Mathematics for Class 10 by R D Sharma (Examin...
# 94  Mathematics for Class 9 by R D Sharma (Examina...
# 88  Ruskin Bond - Best Selling Children Story Book...
#
#                       Author  Rating  Customers_Rated  Price
# 39                     NCERT     4.1              787    780
# 52               James Clear     4.6            18963    651
# 6              M. Laxmikanth     4.6             8547    632
# 66             R.S. Aggarwal     4.4             5047    570
# 46       MTG Editorial Board     4.6             1461    560
# 86           Nitin Singhania     4.6             2542    550
# 97             M. Laxmikanth     4.5             2573    540
# 72                Kabir Bedi     4.4               44    524
# 65           Benjamin Graham     4.5            23275    516
# 55  Antoine de Saint-Exupéry     4.5              587    499
# 8               R S Aggarwal     4.4            11690    470
# 12        Robert T. Kiyosaki     4.6            40453    460
# 58               R.D. Sharma     4.6             1494    452
# 94               R.D. Sharma     4.6             1056    435
# 88               Ruskin Bond     4.5             1004    419

# %%
# Importing bokehJS library for displaying geometrical graphs
from bokeh.models import ColumnDataSource
from bokeh.transform import dodge
import math
from bokeh.io import curdoc
curdoc().clear()
from bokeh.io import push_notebook, show, output_notebook
from bokeh.layouts import row
from bokeh.plotting import figure
from bokeh.transform import factor_cmap
from bokeh.models import Legend
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1001">Loading BokehJS ...</span>
#     </div>

# %%
#Top Rated Books and Authors wrt Customers Rated
data = df[df['Customers_Rated'] > 1000]
data = data.sort_values(['Rating'],axis=0, ascending=False)[:15]
data
# Out:
#                                             Book Name  \
# 37           Harry Potter and the Philosopher's Stone
# 49                   Bhagavad Gita: Yatharoop (Hindi)
# 26  Think Like a Monk: The secret of how to harnes...
# 53  Death; An Inside Story: A book for all those w...
# 23  The Magic of the Lost Temple: Illustrated, eas...
# 18              Sapiens: A Brief History of Humankind
# 20  Life's Amazing Secrets: How to Find Balance an...
# 82  The Theory of Everything: The Origin and Fate ...
# 86  Indian Art and Culture for Civil Services and ...
# 38  Refreshing Mandala - Colouring Book for Adults...
# 89  Mandala Art: Colouring Books for Adults with T...
# 75                            Autobiography of a Yogi
# 90  Concept of Physics Part-2 (2019-2020 Session) ...
# 52  Atomic Habits: The life-changing million copy ...
# 25  Concept of Physics Part-1 (2019-2020 Session) ...
#
#                                   Author  Rating  Customers_Rated  Price
# 37                          J.K. Rowling     4.7            26941    280
# 49  A.C. Bhaktivendanta Swami Prabhupada     4.7             6080    188
# 26                            Jay Shetty     4.7            13180    313
# 53                              Sadhguru     4.7             4620    206
# 23                           Sudha Murty     4.7             2390    148
# 18                     Yuval Noah Harari     4.7            32651    370
# 20                        Gaur Gopal Das     4.6             7459    158
# 82                       Stephen Hawking     4.6             5525    169
# 86                       Nitin Singhania     4.6             2542    550
# 38                Dreamland Publications     4.6             3478    166
# 89                    Wonder House Books     4.6             1080    129
# 75                 Paramahansa Yogananda     4.6             3234     99
# 90                            H.C. Verma     4.6             4284    375
# 52                           James Clear     4.6            18963    651
# 25                            H.C. Verma     4.6             5237    347

# %%
#Most Customer Rated Authors and Books
data = df.sort_values(["Customers_Rated"], axis=0, ascending=False)[:20]
data
# Out:
#                                             Book Name              Author  \
# 67  The Silent Patient: The record-breaking, multi...    Alex Michaelides
# 9                                       The Alchemist        Paulo Coelho
# 21                                Think and Grow Rich       Napoleon Hill
# 12  Rich Dad Poor Dad: What the Rich Teach Their K...  Robert T. Kiyosaki
# 18              Sapiens: A Brief History of Humankind   Yuval Noah Harari
# 16                The Power of Your Subconscious Mind       Joseph Murphy
# 31  Man's Search For Meaning: The classic tribute ...     Viktor E Frankl
# 37           Harry Potter and the Philosopher's Stone        J.K. Rowling
# 92  A Man Called Ove: The life-affirming bestselle...     Fredrik Backman
# 65  The Intelligent Investor (English) Paperback –...     Benjamin Graham
# 2   My First Library: Boxset of 10 Board Books for...  Wonder House Books
# 11                               Word Power Made Easy        Norman Lewis
# 30                               Word Power Made Easy        Norman Lewis
# 70                                  Pride & Prejudice         Jane Austen
# 52  Atomic Habits: The life-changing million copy ...         James Clear
# 48                         The Richest Man in Babylon    George S. Clason
# 3   Ikigai: The Japanese secret to a long and happ...       Héctor García
# 26  Think Like a Monk: The secret of how to harnes...          Jay Shetty
# 28                                  Wuthering Heights        Emily Brontë
# 71  The 5 AM Club: Own Your Morning, Elevate Your ...        Robin Sharma
#
#     Rating  Customers_Rated  Price
# 67     4.5            68398    305
# 9      4.6            53169    240
# 21     4.5            47255    139
# 12     4.6            40453    460
# 18     4.7            32651    370
# 16     4.5            31057    141
# 31     4.5            30437    205
# 37     4.7            26941    280
# 92     4.6            26090    255
# 65     4.5            23275    516
# 2      4.5            22879    399
# 11     4.4            20448     91
# 30     4.4            20448     95
# 70     4.5            19765     99
# 52     4.6            18963    651
# 48     4.4            17538     99
# 3      4.6            14155    329
# 26     4.7            13180    313
# 28     4.5            13031     99
# 71     4.4            11826    257

# %%
from bokeh.transform import factor_cmap
from bokeh.models import Legend
from bokeh.palettes import Dark2_5 as palette
import itertools
from bokeh.palettes import d3
#colors has a list of colors which can be used in plots
colors = itertools.cycle(palette)

palette = d3['Category20'][20]

# %%
index_cmap = factor_cmap('Author', palette=palette,
                         factors=data["Author"])

# %%
p = figure(plot_width=700, plot_height=700, title = "Top Authors: Rating vs. Customers Rated")
p.scatter('Rating','Customers_Rated',source=data,fill_alpha=0.6, fill_color=index_cmap,size=20,legend='Author')
p.xaxis.axis_label = 'RATING'
p.yaxis.axis_label = 'CUSTOMERS RATED'
p.legend.location = 'top_left'
# Out:
# BokehDeprecationWarning: 'legend' keyword is deprecated, use explicit 'legend_label', 'legend_field', or 'legend_group' keywords instead

# %%
show(p)
# Out:
#   <div class="bk-root" id="42d37c98-c96d-4a86-9aa8-145ae2ea1da9" data-root-id="1003"></div>

# %% [markdown]
# # Conclusion:
# In this assignment we have carried out the web scrapping of a web page. In this we considered the Amazon best selling books webpage and we also considered the second page and extracted the information such as book name, author, rate of rating, price using http request and beautiful soup inbuilt package and then stored the data into one csv file. At last we did preprocessing on the scrapped data.
